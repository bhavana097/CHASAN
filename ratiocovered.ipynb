# %%
from skimage import io
import cv2
import matplotlib.pyplot as plt 
import numpy as np
from PIL import Image

# %%
# conda install opencv

# %%
img = cv2.imread('sample.png')
img2 = io.imread('sample.png')

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
print(img2.shape)
# Out:
# (2496, 2434, 3)
# (2496, 2434, 4)

# %%
img
# Out:
# array([[[115, 186, 224],
#         [ 99, 169, 205],
#         [ 97, 172, 220],
#         ...,
#         [ 91, 153, 187],
#         [126, 192, 228],
#         [136, 209, 229]],
#
#        [[128, 201, 239],
#         [105, 183, 230],
#         [ 97, 172, 220],
#         ...,
#         [ 68, 120, 155],
#         [ 91, 153, 187],
#         [107, 179, 207]],
#
#        [[128, 201, 239],
#         [105, 183, 230],
#         [ 88, 162, 211],
#         ...,
#         [ 62, 105, 137],
#         [ 83, 133, 156],
#         [ 68, 120, 155]],
#
#        ...,
#
#        [[199, 214, 209],
#         [225, 238, 235],
#         [225, 238, 235],
#         ...,
#         [ 93, 174, 237],
#         [ 93, 174, 237],
#         [ 93, 174, 237]],
#
#        [[199, 214, 209],
#         [199, 214, 209],
#         [199, 214, 209],
#         ...,
#         [ 93, 174, 237],
#         [ 93, 174, 237],
#         [ 93, 174, 237]],
#
#        [[196, 225, 229],
#         [196, 225, 229],
#         [199, 214, 209],
#         ...,
#         [ 93, 174, 237],
#         [ 93, 174, 237],
#         [ 93, 174, 237]]], dtype=uint8)

# %%
img2
# Out:
# array([[[224, 186, 115, 255],
#         [205, 169,  99, 255],
#         [220, 172,  97, 255],
#         ...,
#         [187, 153,  91, 255],
#         [228, 192, 126, 255],
#         [229, 209, 136, 255]],
#
#        [[239, 201, 128, 255],
#         [230, 183, 105, 255],
#         [220, 172,  97, 255],
#         ...,
#         [155, 120,  68, 255],
#         [187, 153,  91, 255],
#         [207, 179, 107, 255]],
#
#        [[239, 201, 128, 255],
#         [230, 183, 105, 255],
#         [211, 162,  88, 255],
#         ...,
#         [137, 105,  62, 255],
#         [156, 133,  83, 255],
#         [155, 120,  68, 255]],
#
#        ...,
#
#        [[209, 214, 199, 255],
#         [235, 238, 225, 255],
#         [235, 238, 225, 255],
#         ...,
#         [237, 174,  93, 255],
#         [237, 174,  93, 255],
#         [237, 174,  93, 255]],
#
#        [[209, 214, 199, 255],
#         [209, 214, 199, 255],
#         [209, 214, 199, 255],
#         ...,
#         [237, 174,  93, 255],
#         [237, 174,  93, 255],
#         [237, 174,  93, 255]],
#
#        [[229, 225, 196, 255],
#         [229, 225, 196, 255],
#         [209, 214, 199, 255],
#         ...,
#         [237, 174,  93, 255],
#         [237, 174,  93, 255],
#         [237, 174,  93, 255]]], dtype=uint8)

# %%
plt.title('Sample')  # RGB
plt.imshow(img)
plt.show()
# plt.imshow(img2)
# plt.show()

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
# org_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.imshow(org_img)

# %%
# print(org_img)

# %%
plt.imshow(hsv)

# %%
# #120,120,188
# #62,62,123
lower_blue = np.array([180,0,0])
upper_blue = np.array([255,140,100])

# lower_blue = np.array([ 96, 176, 160])
# upper_blue = np.array([116, 196, 255])

# %%
#black & white mask
image_mask = cv2.inRange(img,lower_blue,upper_blue)

# %%
image_mask=255-image_mask

# %%
cv2.imshow("hello",image_mask)
cv2.waitKey(0)
# Out:
# -1

# %%
#bright color mask
# hsvOutput = cv2.bitwise_and(img, img, mask=image_mask)

# %%
cv2.imshow("hello",img)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2. imwrite("result.png",image_mask)
# Out:
# True

# %%
ratio_blue = cv2.countNonZero(image_mask)/(img.size/3)
panel_uncovered = np.round(100-ratio_blue*100, 2)
print(' ratio of panel', ratio_blue )
print(' pixel percentage:', panel_uncovered )
# Out:
#  ratio of panel 0.8231555040241872
#  pixel percentage: 17.68

# %%
per_biofouling = 100 - panel_uncovered
print('percentage of biofouling', per_biofouling )
# Out:
# percentage of biofouling 82.32
